# %% [markdown]
# # UC1: Feature Engineering - Late Payment Risk

# %% [markdown]
# ## 0. Setup

# %%
# %pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: pandas in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from -r ../requirements.txt (line 1)) (2.3.3)
# Requirement already satisfied: numpy in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from -r ../requirements.txt (line 2)) (2.4.1)
# Requirement already satisfied: scikit-learn in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from -r ../requirements.txt (line 3)) (1.8.0)
# Requirement already satisfied: matplotlib in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from -r ../requirements.txt (line 4)) (3.10.8)
# Requirement already satisfied: seaborn in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from -r ../requirements.txt (line 5)) (0.13.2)
# Requirement already satisfied: jupyter in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from -r ../requirements.txt (line 6)) (1.1.1)
# Requirement already satisfied: ipykernel in c:\users\pc\appdata\roaming\python\python314\site-packages (from -r ../requirements.txt (line 7)) (7.1.0)
# Requirement already satisfied: mlflow in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from -r ../requirements.txt (line 8)) (3.8.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pc\appdata\roaming\python\python314\site-packages (from pandas->-r ../requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from pandas->-r ../requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from pandas->-r ../requirements.txt (line 1)) (2025.3)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from scikit-learn->-r ../requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from scikit-learn->-r ../requirements.txt (line 3)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from scikit-learn->-r ../requirements.txt (line 3)) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from matplotlib->-r ../requirements.txt (line 4)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from matplotlib->-r ../requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from matplotlib->-r ../requirements.txt (line 4)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from matplotlib->-r ../requirements.txt (line 4)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from matplotlib->-r ../requirements.txt (line 4)) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from matplotlib->-r ../requirements.txt (line 4)) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from matplotlib->-r ../requirements.txt (line 4)) (3.3.1)
# Requirement already satisfied: notebook in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from jupyter->-r ../requirements.txt (line 6)) (7.5.2)
# Requirement already satisfied: jupyter-console in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from jupyter->-r ../requirements.txt (line 6)) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from jupyter->-r ../requirements.txt (line 6)) (7.16.6)
# Requirement already satisfied: ipywidgets in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from jupyter->-r ../requirements.txt (line 6)) (8.1.8)
# Requirement already satisfied: jupyterlab in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from jupyter->-r ../requirements.txt (line 6)) (4.5.2)
# Requirement already satisfied: comm>=0.1.1 in c:\users\pc\appdata\roaming\python\python314\site-packages (from ipykernel->-r ../requirements.txt (line 7)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\pc\appdata\roaming\python\python314\site-packages (from ipykernel->-r ../requirements.txt (line 7)) (1.8.19)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\pc\appdata\roaming\python\python314\site-packages (from ipykernel->-r ../requirements.txt (line 7)) (9.9.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in c:\users\pc\appdata\roaming\python\python314\site-packages (from ipykernel->-r ../requirements.txt (line 7)) (8.8.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\pc\appdata\roaming\python\python314\site-packages (from ipykernel->-r ../requirements.txt (line 7)) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\pc\appdata\roaming\python\python314\site-packages (from ipykernel->-r ../requirements.txt (line 7)) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\pc\appdata\roaming\python\python314\site-packages (from ipykernel->-r ../requirements.txt (line 7)) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\pc\appdata\roaming\python\python314\site-packages (from ipykernel->-r ../requirements.txt (line 7)) (7.2.1)
# Requirement already satisfied: pyzmq>=25 in c:\users\pc\appdata\roaming\python\python314\site-packages (from ipykernel->-r ../requirements.txt (line 7)) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\pc\appdata\roaming\python\python314\site-packages (from ipykernel->-r ../requirements.txt (line 7)) (6.5.4)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\pc\appdata\roaming\python\python314\site-packages (from ipykernel->-r ../requirements.txt (line 7)) (5.14.3)
# Requirement already satisfied: mlflow-skinny==3.8.1 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from mlflow->-r ../requirements.txt (line 8)) (3.8.1)
# Requirement already satisfied: mlflow-tracing==3.8.1 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from mlflow->-r ../requirements.txt (line 8)) (3.8.1)
# Requirement already satisfied: Flask-CORS<7 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from mlflow->-r ../requirements.txt (line 8)) (6.0.2)
# Requirement already satisfied: Flask<4 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from mlflow->-r ../requirements.txt (line 8)) (3.1.2)
# Requirement already satisfied: alembic!=1.10.0,<2 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from mlflow->-r ../requirements.txt (line 8)) (1.18.1)
# Requirement already satisfied: cryptography<47,>=43.0.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from mlflow->-r ../requirements.txt (line 8)) (46.0.3)
# Requirement already satisfied: docker<8,>=4.0.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from mlflow->-r ../requirements.txt (line 8)) (7.1.0)
# Requirement already satisfied: graphene<4 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from mlflow->-r ../requirements.txt (line 8)) (3.4.3)
# Requirement already satisfied: huey<3,>=2.5.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from mlflow->-r ../requirements.txt (line 8)) (2.6.0)
# Requirement already satisfied: pyarrow<23,>=4.0.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from mlflow->-r ../requirements.txt (line 8)) (22.0.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from mlflow->-r ../requirements.txt (line 8)) (2.0.45)
# Requirement already satisfied: waitress<4 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from mlflow->-r ../requirements.txt (line 8)) (3.0.2)
# Requirement already satisfied: cachetools<7,>=5.0.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from mlflow-skinny==3.8.1->mlflow->-r ../requirements.txt (line 8)) (6.2.4)
# Requirement already satisfied: click<9,>=7.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from mlflow-skinny==3.8.1->mlflow->-r ../requirements.txt (line 8)) (8.3.1)
# Requirement already satisfied: cloudpickle<4 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from mlflow-skinny==3.8.1->mlflow->-r ../requirements.txt (line 8)) (3.1.2)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from mlflow-skinny==3.8.1->mlflow->-r ../requirements.txt (line 8)) (0.78.0)
# Requirement already satisfied: fastapi<1 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from mlflow-skinny==3.8.1->mlflow->-r ../requirements.txt (line 8)) (0.128.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from mlflow-skinny==3.8.1->mlflow->-r ../requirements.txt (line 8)) (3.1.46)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from mlflow-skinny==3.8.1->mlflow->-r ../requirements.txt (line 8)) (8.7.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from mlflow-skinny==3.8.1->mlflow->-r ../requirements.txt (line 8)) (1.39.1)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from mlflow-skinny==3.8.1->mlflow->-r ../requirements.txt (line 8)) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from mlflow-skinny==3.8.1->mlflow->-r ../requirements.txt (line 8)) (1.39.1)
# Requirement already satisfied: protobuf<7,>=3.12.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from mlflow-skinny==3.8.1->mlflow->-r ../requirements.txt (line 8)) (6.33.4)
# Requirement already satisfied: pydantic<3,>=2.0.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from mlflow-skinny==3.8.1->mlflow->-r ../requirements.txt (line 8)) (2.12.5)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from mlflow-skinny==3.8.1->mlflow->-r ../requirements.txt (line 8)) (1.2.1)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from mlflow-skinny==3.8.1->mlflow->-r ../requirements.txt (line 8)) (6.0.3)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from mlflow-skinny==3.8.1->mlflow->-r ../requirements.txt (line 8)) (2.32.5)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from mlflow-skinny==3.8.1->mlflow->-r ../requirements.txt (line 8)) (0.5.5)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from mlflow-skinny==3.8.1->mlflow->-r ../requirements.txt (line 8)) (4.15.0)
# Requirement already satisfied: uvicorn<1 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from mlflow-skinny==3.8.1->mlflow->-r ../requirements.txt (line 8)) (0.40.0)
# Requirement already satisfied: Mako in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from alembic!=1.10.0,<2->mlflow->-r ../requirements.txt (line 8)) (1.3.10)
# Requirement already satisfied: colorama in c:\users\pc\appdata\roaming\python\python314\site-packages (from click<9,>=7.0->mlflow-skinny==3.8.1->mlflow->-r ../requirements.txt (line 8)) (0.4.6)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from cryptography<47,>=43.0.0->mlflow->-r ../requirements.txt (line 8)) (2.0.0)
# Requirement already satisfied: google-auth~=2.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.8.1->mlflow->-r ../requirements.txt (line 8)) (2.47.0)
# Requirement already satisfied: pywin32>=304 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from docker<8,>=4.0.0->mlflow->-r ../requirements.txt (line 8)) (311)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from docker<8,>=4.0.0->mlflow->-r ../requirements.txt (line 8)) (2.5.0)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from fastapi<1->mlflow-skinny==3.8.1->mlflow->-r ../requirements.txt (line 8)) (0.50.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from fastapi<1->mlflow-skinny==3.8.1->mlflow->-r ../requirements.txt (line 8)) (0.0.4)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from Flask<4->mlflow->-r ../requirements.txt (line 8)) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from Flask<4->mlflow->-r ../requirements.txt (line 8)) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from Flask<4->mlflow->-r ../requirements.txt (line 8)) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from Flask<4->mlflow->-r ../requirements.txt (line 8)) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from Flask<4->mlflow->-r ../requirements.txt (line 8)) (3.1.5)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.8.1->mlflow->-r ../requirements.txt (line 8)) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.8.1->mlflow->-r ../requirements.txt (line 8)) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.8.1->mlflow->-r ../requirements.txt (line 8)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.8.1->mlflow->-r ../requirements.txt (line 8)) (4.9.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from graphene<4->mlflow->-r ../requirements.txt (line 8)) (3.2.7)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from graphene<4->mlflow->-r ../requirements.txt (line 8)) (3.2.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.8.1->mlflow->-r ../requirements.txt (line 8)) (3.23.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.8.1->mlflow->-r ../requirements.txt (line 8)) (0.60b1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.8.1->mlflow->-r ../requirements.txt (line 8)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.8.1->mlflow->-r ../requirements.txt (line 8)) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.8.1->mlflow->-r ../requirements.txt (line 8)) (0.4.2)
# Requirement already satisfied: six>=1.5 in c:\users\pc\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.8.2->pandas->-r ../requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.8.1->mlflow->-r ../requirements.txt (line 8)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.8.1->mlflow->-r ../requirements.txt (line 8)) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.8.1->mlflow->-r ../requirements.txt (line 8)) (2025.10.5)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.8.1->mlflow->-r ../requirements.txt (line 8)) (0.6.1)
# Requirement already satisfied: greenlet>=1 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow->-r ../requirements.txt (line 8)) (3.3.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.8.1->mlflow->-r ../requirements.txt (line 8)) (4.12.1)
# Requirement already satisfied: h11>=0.8 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from uvicorn<1->mlflow-skinny==3.8.1->mlflow->-r ../requirements.txt (line 8)) (0.16.0)
# Requirement already satisfied: pycparser in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from cffi>=2.0.0->cryptography<47,>=43.0.0->mlflow->-r ../requirements.txt (line 8)) (2.23)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\pc\appdata\roaming\python\python314\site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 7)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\pc\appdata\roaming\python\python314\site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 7)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\pc\appdata\roaming\python\python314\site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 7)) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\pc\appdata\roaming\python\python314\site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 7)) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\pc\appdata\roaming\python\python314\site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 7)) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\pc\appdata\roaming\python\python314\site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 7)) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\pc\appdata\roaming\python\python314\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 7)) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\pc\appdata\roaming\python\python314\site-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 7)) (0.8.5)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\pc\appdata\roaming\python\python314\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->-r ../requirements.txt (line 7)) (4.5.1)
# Requirement already satisfied: executing>=1.2.0 in c:\users\pc\appdata\roaming\python\python314\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 7)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\pc\appdata\roaming\python\python314\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 7)) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\pc\appdata\roaming\python\python314\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 7)) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from ipywidgets->jupyter->-r ../requirements.txt (line 6)) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from ipywidgets->jupyter->-r ../requirements.txt (line 6)) (3.0.16)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 6)) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 6)) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 6)) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 6)) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 6)) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 6)) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 6)) (80.9.0)
# Requirement already satisfied: httpcore==1.* in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r ../requirements.txt (line 6)) (1.0.9)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 6)) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 6)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 6)) (0.5.4)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 6)) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 6)) (0.24.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 6)) (3.0.2)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 6)) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 6)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 6)) (1.9.0)
# Requirement already satisfied: babel>=2.10 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 6)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 6)) (0.13.0)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 6)) (4.26.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 6)) (25.1.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 6)) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 6)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 6)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 6)) (0.30.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 6)) (4.0.0)
# Requirement already satisfied: rfc3339-validator in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 6)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 6)) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 6)) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 6)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 6)) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 6)) (1.1.0)
# Requirement already satisfied: uri-template in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 6)) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 6)) (4.14.2)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r ../requirements.txt (line 6)) (6.3.0)
# Requirement already satisfied: defusedxml in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 6)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 6)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 6)) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 6)) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 6)) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->-r ../requirements.txt (line 6)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r ../requirements.txt (line 6)) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 6)) (2.21.2)
# Requirement already satisfied: lark>=1.2.2 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from beautifulsoup4->nbconvert->jupyter->-r ../requirements.txt (line 6)) (2.8)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\pc\appdata\local\programs\python\python314\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 6)) (1.4.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))

import pandas as pd
import numpy as np
from src.config import SILVER_FILES, GOLD_UC1_FILE, GOLD_UC1_FEATURES, ID_COLS, TARGET
from src.uc1_late_risk.features import build_gold_features

# %% [markdown]
# ## 1. Load & Validate Raw Data

# %% [markdown]
# ### 1.1 Load Data

# %%
data_dict = {}
for name, filepath in SILVER_FILES.items():
    data_dict[name] = pd.read_csv(filepath)
    print(f"Loaded {name}: {data_dict[name].shape}")
# Out:
# Loaded users: (1000, 7)
# Loaded orders: (2953, 8)
# Loaded installments: (5238, 9)
# Loaded payments: (5084, 9)
# Loaded disputes: (147, 7)
# Loaded refunds: (95, 6)
# Loaded merchants: (120, 7)
# Loaded checkout_events: (5474, 5)

# %% [markdown]
# ### 1.2 Data Quality Validation

# %%
def validate_raw_data(data_dict):
    """Validate raw data quality"""
    issues = []
    
    for name, df in data_dict.items():
        # Check for completely empty columns
        empty_cols = df.columns[df.isnull().all()].tolist()
        if empty_cols:
            issues.append(f"{name}: Empty columns {empty_cols}")
        
        # Check for duplicate IDs
        id_col = [c for c in df.columns if c.endswith('_id')][0]
        if df[id_col].duplicated().any():
            issues.append(f"{name}: Duplicate IDs in {id_col}")
        
        # Check critical nulls
        if name == "installments":
            if df["due_date"].isnull().any():
                issues.append(f"{name}: NULL due_dates found")
    
    if issues:
        print("\n".join(issues))
        raise ValueError("Data validation failed!")
    else:
        print("All raw data validation checks passed")

validate_raw_data(data_dict)
# Out:
# All raw data validation checks passed

# %% [markdown]
# ### 1.3 Data Profiling

# %%
for name, df in data_dict.items():
    print(f"\n=== {name} ({df.shape}) ===")
    print(f"Columns: {df.columns.tolist()}")
    print(f"Missing: {df.isnull().sum().sum()} cells")
    print(f"Duplicates: {df.duplicated().sum()} rows")
# Out:
# === users ((1000, 7)) ===
# Columns: ['user_id', 'signup_date', 'kyc_level', 'city', 'account_status', 'created_at', 'updated_at']
# Missing: 0 cells
# Duplicates: 0 rows
#
# === orders ((2953, 8)) ===
# Columns: ['order_id', 'user_id', 'merchant_id', 'order_date', 'amount', 'currency', 'installments_count', 'status']
# Missing: 0 cells
# Duplicates: 0 rows
#
# === installments ((5238, 9)) ===
# Columns: ['installment_id', 'order_id', 'user_id', 'merchant_id', 'installment_number', 'due_date', 'paid_date', 'status', 'late_days']
# Missing: 828 cells
# Duplicates: 0 rows
#
# === payments ((5084, 9)) ===
# Columns: ['payment_id', 'installment_id', 'order_id', 'user_id', 'merchant_id', 'payment_date', 'amount', 'payment_channel', 'status']
# Missing: 0 cells
# Duplicates: 0 rows
#
# === disputes ((147, 7)) ===
# Columns: ['dispute_id', 'order_id', 'user_id', 'merchant_id', 'dispute_date', 'reason', 'status']
# Missing: 0 cells
# Duplicates: 0 rows
#
# === refunds ((95, 6)) ===
# Columns: ['refund_id', 'order_id', 'user_id', 'merchant_id', 'refund_date', 'amount']
# Missing: 0 cells
# Duplicates: 0 rows
#
# === merchants ((120, 7)) ===
# Columns: ['merchant_id', 'merchant_name', 'category', 'city', 'merchant_status', 'created_at', 'updated_at']
# Missing: 0 cells
# Duplicates: 0 rows
#
# === checkout_events ((5474, 5)) ===
# Columns: ['checkout_event_id', 'order_id', 'user_id', 'event_type', 'event_date']
# Missing: 0 cells
# Duplicates: 0 rows

# %% [markdown]
# ## 2. Build Gold Features

# %%
print("Building features...")
gold_uc1 = build_gold_features(SILVER_FILES)

print(f"Gold features created: {gold_uc1.shape}")
gold_uc1.head()
# Out:
# Building features...
# Gold features created: (4824, 49)
#   installment_id      order_id     user_id    merchant_id  installment_number  \
# 0   inst_0000001  order_000006  user_00002  merchant_0109                   1
# 1   inst_0000003  order_000006  user_00002  merchant_0109                   3
# 2   inst_0000004  order_000007  user_00002  merchant_0053                   1
# 3   inst_0000005  order_000007  user_00002  merchant_0053                   2
# 4   inst_0000006  order_000007  user_00002  merchant_0053                   3
#
#     due_date  paid_date status  late_days anchor_date  ...  \
# 0 2026-01-31 2026-01-30   paid        0.0  2026-01-31  ...
# 1 2026-04-01 2026-04-06   late        5.0  2026-04-01  ...
# 2 2025-12-10 2025-12-10   paid        0.0  2025-12-10  ...
# 3 2026-01-09 2026-01-08   paid        0.0  2026-01-09  ...
# 4 2026-02-08 2026-02-07   paid        0.0  2026-02-08  ...
#
#    checkout_abandon_rate_30d  checkout_friction_score merchant_name  \
# 0                        0.5                 1.693147  Merchant 109
# 1                        0.0                 0.000000  Merchant 109
# 2                        0.0                 0.000000   Merchant 53
# 3                        0.0                 0.000000   Merchant 53
# 4                        1.0                 2.693147   Merchant 53
#
#       category city_merchant merchant_status  merchant_status_num  \
# 0  electronics    Casablanca          active                    1
# 1  electronics    Casablanca          active                    1
# 2       travel     Marrakech          active                    1
# 3       travel     Marrakech          active                    1
# 4       travel     Marrakech          active                    1
#
#    merchant_dispute_rate_90d  merchant_refund_rate_90d  merchant_risk_score
# 0                   0.000000                  0.000000             0.000000
# 1                   0.000000                  0.000000             0.000000
# 2                   0.000000                  0.000000             0.000000
# 3                   0.130435                  0.043478             0.304348
# 4                   0.166667                  0.111111             0.444444
#
# [5 rows x 49 columns]

# %% [markdown]
# ## 3. Feature Validation (CRITICAL!)

# %% [markdown]
# ### 3.1 Schema Validation

# %%
# Check required columns exist
required_cols = set(ID_COLS + [TARGET] + GOLD_UC1_FEATURES)
missing_cols = required_cols - set(gold_uc1.columns)
if missing_cols:
    raise ValueError(f"Missing columns: {missing_cols}")
print("All required columns present")
# Out:
# All required columns present

# %% [markdown]
# ### 3.2 Data Quality Checks

# %%
print("\n=== Data Quality Validation ===")

# Duplicates
dup_rows = gold_uc1.duplicated().sum()
dup_inst = gold_uc1["installment_id"].duplicated().sum()
print(f"Duplicated rows: {dup_rows}, Duplicated IDs: {dup_inst}")
if dup_inst > 0:
    raise ValueError("Duplicate installment IDs found!")

# Target distribution
print(f"\nTarget balance:")
print(gold_uc1[TARGET].value_counts())
print(f"Late rate: {gold_uc1[TARGET].mean():.2%}")

if gold_uc1[TARGET].mean() < 0.01 or gold_uc1[TARGET].mean() > 0.99:
    print("WARNING: Extreme class imbalance detected")

# Check for NaN in target
if gold_uc1[TARGET].isnull().any():
    raise ValueError("NULL values in target!")
# Out:
# === Data Quality Validation ===
# Duplicated rows: 0, Duplicated IDs: 0
#
# Target balance:
# is_late
# 0    3869
# 1     955
# Name: count, dtype: int64
# Late rate: 19.80%

# %% [markdown]
# ### 3.3 Feature Quality Validation

# %%
print("\n=== Feature Quality Validation ===")

# Missing data
miss = gold_uc1[GOLD_UC1_FEATURES].isnull().mean().sort_values(ascending=False)
print("\nTop 10 features by missingness:")
print(miss.head(10))

high_missing = miss[miss > 0.8].index.tolist()
if high_missing:
    print(f"WARNING: Features with >80% missing: {high_missing}")

# Constant features (will be removed in training)
const_features = [c for c in GOLD_UC1_FEATURES 
                  if gold_uc1[c].nunique(dropna=False) <= 1]
print(f"\nConstant features (will be auto-removed): {const_features}")

# Check for infinite values
inf_features = [c for c in GOLD_UC1_FEATURES 
                if gold_uc1[c].dtype in ['float64', 'int64'] 
                and np.isinf(gold_uc1[c]).any()]
if inf_features:
    raise ValueError(f"Infinite values in: {inf_features}")
# Out:
# === Feature Quality Validation ===
#
# Top 10 features by missingness:
# sum_order_amount_30d        0.523217
# avg_order_amount_30d        0.523217
# max_order_amount_30d        0.523217
# avg_late_days_90d           0.156716
# on_time_payment_rate_90d    0.156716
# max_late_days_90d           0.156716
# late_payment_rate_90d       0.156716
# account_age_days            0.000000
# user_city                   0.000000
# kyc_level_num               0.000000
# dtype: float64
#
# Constant features (will be auto-removed): ['currency', 'merchant_status_num']

# %% [markdown]
# ### 3.4 Leakage Detection (CRITICAL!)

# %%
print("\n=== Leakage Detection ===")

# Features that should NOT be in the dataset
leakage_keywords = ["paid_date", "late_days", "status", "payment_date"]
leakage_cols = [c for c in gold_uc1.columns 
                if any(kw in c.lower() for kw in leakage_keywords)]

# These are OK in the dataset for ID/audit, but NOT in features
leakage_in_features = [c for c in leakage_cols if c in GOLD_UC1_FEATURES]

if leakage_in_features:
    raise ValueError(f"LEAKAGE DETECTED in features: {leakage_in_features}")
else:
    print("No leakage detected in feature list")

print(f"Leakage columns present (but not in features): {leakage_cols}")
# Out:
# === Leakage Detection ===
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 12
#       9 leakage_in_features = [c for c in leakage_cols if c in GOLD_UC1_FEATURES]
#      11 if leakage_in_features:
# ---> 12     raise ValueError(f"LEAKAGE DETECTED in features: {leakage_in_features}")
#      13 else:
#      14     print("No leakage detected in feature list")
#
# ValueError: LEAKAGE DETECTED in features: ['account_status_num', 'avg_late_days_90d', 'max_late_days_90d', 'merchant_status_num']

# %% [markdown]
# ### 3.5 Temporal Consistency

# %%
# Ensure anchor_date is not null
if gold_uc1["anchor_date"].isnull().any():
    raise ValueError("NULL anchor_dates found!")

# Check date logic
gold_uc1["anchor_date"] = pd.to_datetime(gold_uc1["anchor_date"])
if (gold_uc1["account_age_days"] < 0).any():
    print("WARNING: Negative account ages detected")

# %% [markdown]
# ### 3.6 Numeric Distribution Checks

# %%
print("\n=== Numeric Distribution Validation ===")

numeric_features = gold_uc1[GOLD_UC1_FEATURES].select_dtypes(include=['number']).columns

# Check for suspicious distributions
for col in numeric_features:
    data = gold_uc1[col].dropna()
    if len(data) > 0:
        q99 = data.quantile(0.99)
        q01 = data.quantile(0.01)
        
        # Check for extreme outliers (>100x difference)
        if q99 > 0 and q01 > 0 and (q99 / q01) > 100:
            print(f"{col}: Extreme range detected (1%={q01:.2f}, 99%={q99:.2f})")

# %% [markdown]
# ## 4. Generate Validation Report

# %%
validation_report = {
    "dataset_shape": gold_uc1.shape,
    "n_features": len(GOLD_UC1_FEATURES),
    "n_constant_features": len(const_features),
    "target_mean": gold_uc1[TARGET].mean(),
    "duplicates": dup_rows,
    "max_missing_rate": miss.max(),
    "validation_timestamp": pd.Timestamp.now()
}

print("\n=== Validation Report ===")
for k, v in validation_report.items():
    print(f"{k}: {v}")

# %% [markdown]
# ## 5. Save Gold Dataset

# %%
gold_uc1.to_csv(GOLD_UC1_FILE, index=False)
print(f"\nSaved: {GOLD_UC1_FILE}")
print(f"Shape: {gold_uc1.shape}")
print(f"Features: {len(GOLD_UC1_FEATURES)}")
